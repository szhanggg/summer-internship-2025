# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
datapath = "/explore/nobackup/projects/pix4dcloud/szhang16/test_results/"
sample_data = np.load(datapath + "None.npy")

# %%
sample_data
# Out:
# array([0.5787546 , 0.6556777 , 0.73357666, ..., 0.        , 0.        ,
#        0.        ], dtype=float32)

# %%
plt.hist(sample_data)
plt.show()
